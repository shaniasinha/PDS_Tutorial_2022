# %% [markdown]
# <a href="https://colab.research.google.com/github/shaniasinha/PDS_Tutorial_2022/blob/main/PDS_Tutorial_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # So far in your projects:
# - Please x3 comment your code
# - (please upload your notebook/file) :)
# - 3 github links missing 😾

# %% [markdown]
# # Example Project 4 Tutorialzzz
# >Author: Shania Sinha
#
# >Date: 17 November, 2022

# %% [markdown]
# > "Any fool can write code that a computer can understand. Good programmers write code that humans can understand.”
# >
# >
# >> – Martin Fowler

# %% [markdown]
# Some suggested tasks:
#
# 1. Understanding what content is available in different countries (🤓)
# 2. Identifying similar content by matching text-based features (🤨)
# 3. Network analysis of Actors / Directors and find interesting insights (🧐)
# 4. Does Netflix has more focus on TV Shows than movies in recent years? (😏)

# %% [markdown]
# ## Load Libraries

# %%
# Please leave commments in your code!
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Load the dataset

# %%
# Reading a sample dataset
df = pd.read_csv("/content/netflix_titles.csv")

# %% [markdown]
# ## Check the dataset

# %%
# Get preview of the dataset
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
# Check the datatypes for our dataframe using df.dtypes
df.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
# Descriptive statistics of the dataset
df.describe()
# Out:
#        release_year
# count   8807.000000
# mean    2014.180198
# std        8.819312
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %% [markdown]
# Turns out, the descriptive statistics are pretty useless since most of our data is text (strings).

# %%
# Check for null values in the dataset
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
# Check what fraction of all observations is null
for i in df.columns:
    null_rate = df[i].isna().sum() / len(df) * 100
    if null_rate > 0.0:
      print("{}: {}%".format(i,round(null_rate,2)))
# Out:
# director: 29.91%
# cast: 9.37%
# country: 9.44%
# date_added: 0.11%
# rating: 0.05%
# duration: 0.03%

# %% [markdown]
# From the results above, we can see that the variable **director** has the highest number of null values.
#
# **cast** and **country** have similar number of missing (or null) values.

# %% [markdown]
# ## Cleaning the dataset

# %% [markdown]
# Here, we get to make the choice of what we want to keep and what we want to remove from our dataset.
#
# I am making the following choices:
#
# *Remove all rows where **date_added** is null.*
# > **date_added** refers to the date when the media content was added to Netflix. This information is useful for our analysis but the number of missing observations compared to the size of the population is very small.
#
#
# *Remove all rows where **rating** is null.*
# > **rating** refers to the how well-liked the media content is by the audience. This information is useful for our analysis but the number of missing observations compared to the size of the population is very small.
#
#
# *Remove all rows where **duration** is null.*
# > **duration** refers to the length of the media content. This information may be useful for our analysis but the number of missing observations compared to the size of the population is very small.

# %%
# What about the null values in director, cast and country???

# %%
df['country'].mode()
# Out:
# 0    United States
# dtype: object

# %%
# Netflix is an American company and the mode of the 'country' column is the US 
# Should we drop NAs? Or should we assume the country of origin of the show/movie is the USA?

# %%
# I don't want to drop films just because the director isn't listed
# If i do drop those rows, I will lose around 30% of the dataset

# %%
df['director'].replace(np.nan, 'No Data',inplace  = True)

# %%
# I want to conduct a network analysis between directors and actors
# Hence, same as directors, I will replace NA with "No Data"

# %%
df['cast'].replace(np.nan, 'No Data',inplace  = True)

# %%
# I decide that I don't want to lose all the information in a row, even if the country is missing

# %%
df['country'].replace(np.nan, 'No Data',inplace  = True)

# %%
# Get preview of the dataset
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water          No Data
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans          No Data
# 4      s5  TV Show           Kota Factory          No Data
#
#                                                 cast        country  \
# 0                                            No Data  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...        No Data
# 3                                            No Data        No Data
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
# Drop all NA values
df.dropna()
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water          No Data
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans          No Data
# 4         s5  TV Show           Kota Factory          No Data
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb          No Data
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                               No Data  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %% [markdown]
# ### Next Up:
#
#
# *   Change **date** format?
# *   Get started on Visualization :)
